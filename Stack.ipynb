# %% [markdown]
# # Stack

# %% [markdown]
# - It is a linear data structure that follows the Last In First Out (LIFO) principle.
# - It allows adding and removing elements only from one end, called the top of the stack.
# - Common operations include push (to add an element) and pop (to remove the top element).

# %% [markdown]
# # Implementation of Stack in Python

# %%
# Implementation of Stack in Python with operations: is_empty, is_full, push, pop, peek, size
class Stack:
    def __init__(self, capacity=5):
        self.capacity = capacity
        self.stack = []

    def is_empty(self):
        return len(self.stack) == 0

    def is_full(self):
        return len(self.stack) == self.capacity

    def push(self, item):
        if self.is_full():
            print("Stack Overflow")
        else:
            self.stack.append(item)
            print("Item pushed to stack.")

    def pop(self):
        if self.is_empty():
            print("Stack Underflow")
        return self.stack.pop()

    def peek(self):
        if self.is_empty():
            print("Stack Underflow")
        else:
            print("Top element is:", self.stack[-1])

    def size(self):
        return len(self.stack)

# %%
# Example usage
stack = Stack()
print("Is stack empty?", stack.is_empty())
print("Is stack full?", stack.is_full())
stack.push(1)
stack.push(2)
stack.push(3)
stack.push(4)
stack.push(5)
stack.push(6)
print("Is stack full?", stack.is_full())
print("Top element is:", stack.peek())
print("Stack size is:", stack.size())
print("Popped element is:", stack.pop())
print("Is stack empty?", stack.is_empty())
# Out:
# Is stack empty? True
# Is stack full? False
# Item pushed to stack.
# Item pushed to stack.
# Item pushed to stack.
# Item pushed to stack.
# Item pushed to stack.
# Stack Overflow
# Is stack full? True
# Top element is: 5
# Top element is: None
# Stack size is: 5
# Popped element is: 5
# Is stack empty? False

# %% [markdown]
# # Time Complexity
# - Push operation: O(1)
# - Pop operation: O(1)
